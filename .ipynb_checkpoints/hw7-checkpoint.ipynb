# %%
print('1. The Tree class implements a variety of other useful methods. See the Tree help documentation for more details,i.e. import the Tree class and then type help(Tree).\n')
# Out:
# 1. The Tree class implements a variety of other useful methods. See the Tree help documentation for more details,i.e. import the Tree class and then type help(Tree).

# %%
import nltk 
from nltk import CFG
sent = "Kim arrived or Dana left and everyone cheered"
sent = [word for word in sent.split()]
print(sent)
groucho_grammar = CFG.fromstring("""
S -> CP | VP 
CP -> VP C VP | CP C VP | VP C CP
VP -> NP V 
NP -> 'Kim' | 'Dana' | 'everyone'
V -> 'arrived' | 'left' |'cheered'
C -> 'or' | 'and'
""")
print(groucho_grammar.productions())
parser = nltk.ChartParser(groucho_grammar)
trees = parser.parse(sent)
for tree in trees:
    print(tree)
# Out:
# ['Kim', 'arrived', 'or', 'Dana', 'left', 'and', 'everyone', 'cheered']
# [S -> CP, S -> VP, CP -> VP C VP, CP -> CP C VP, CP -> VP C CP, VP -> NP V, NP -> 'Kim', NP -> 'Dana', NP -> 'everyone', V -> 'arrived', V -> 'left', V -> 'cheered', C -> 'or', C -> 'and']
# (S
#   (CP
#     (CP (VP (NP Kim) (V arrived)) (C or) (VP (NP Dana) (V left)))
#     (C and)
#     (VP (NP everyone) (V cheered))))
# (S
#   (CP
#     (VP (NP Kim) (V arrived))
#     (C or)
#     (CP
#       (VP (NP Dana) (V left))
#       (C and)
#       (VP (NP everyone) (V cheered)))))

# %%
print('2.The Tree class implements a variety of other useful methods. See the Tree help documentation for more details, i.e. import the Tree class and then type help(Tree).')
# Out:
# 2.The Tree class implements a variety of other useful methods. See the Tree help documentation for more details, i.e. import the Tree class and then type help(Tree).

# %%
from nltk import tree
help(tree)
# Out:
# Help on module nltk.tree in nltk:
#
# NAME
#     nltk.tree
#
# DESCRIPTION
#     Class for representing hierarchical language structures, such as
#     syntax trees and morphological trees.
#
# CLASSES
#     builtins.list(builtins.object)
#         Tree
#             ImmutableTree
#                 ImmutableMultiParentedTree(ImmutableTree, MultiParentedTree)
#                 ImmutableParentedTree(ImmutableTree, ParentedTree)
#                 ImmutableProbabilisticTree(ImmutableTree, nltk.probability.ProbabilisticMixIn)
#             ProbabilisticTree(Tree, nltk.probability.ProbabilisticMixIn)
#     builtins.object
#         nltk.probability.ProbabilisticMixIn
#     AbstractParentedTree(Tree)
#         MultiParentedTree
#         ParentedTree
#
#     class ImmutableMultiParentedTree(ImmutableTree, MultiParentedTree)
#      |  A ``Tree`` that automatically maintains parent pointers for
#      |  multi-parented trees.  The following are methods for querying the
# ...

# %%
print('Write a recursive function to traverse a tree and return the depth of the tree, such that a tree with a single node would have depth zero. (Hint: the depth of a subtree is the maximum depth of its children, plus one.')
print('def depth(node):')
print('if node is None:')
print('return 0')
print('else')
print('return max(height(node.left), height(node.right)) + 1')
# Out:
# Write a recursive function to traverse a tree and return the depth of the tree, such that a tree with a single node would have depth zero. (Hint: the depth of a subtree is the maximum depth of its children, plus one.
# def depth(node):
# if node is None:
# return 0
# else
# return max(height(node.left), height(node.right)) + 1

# %%
print('Can the grammar in grammar1 be used to describe sentences that are more than 20 words in length?'\n)
print('Yes, it can be used until all words are there in the grammar')
# Out:
# Can the grammar in grammar1 be used to describe sentences that are more than 20 words in length?

# %%
print('Can you come up with grammatical sentences that have probably never been uttered before? (Take turns with a partner.) What does this tell you about human language?')
print('The old man the boats')
print('Since "man" is actually a verb as well, this statement is about a collective group of old people working on some boats.')
# Out:
# Can you come up with grammatical sentences that have probably never been uttered before? (Take turns with a partner.) What does this tell you about human language?
# The old man the boats
# Since "man" is actually a verb as well, this statement is about a collective group of old people working on some boats.
